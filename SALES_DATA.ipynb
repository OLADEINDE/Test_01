# %% [markdown]
# SALES DATA

# %%
import pandas as pd
df =pd.read_excel(r"C:\Users\USER\Desktop\DATA_ANALYSIS-FILES\IMPACT-EDU-SERVICES_DATA_ANALYSIS_Course-Y2024\Examples_Pandas\Sales_Data_PandasFile.xlsx", sheet_name='Summary_Abs')
df
# Out:
#         Countries  Adults (35-64)  Seniors (64+)  Young Adults (25-34)  \
# 0       Australia           10302             58                  9031
# 1          Canada            7089            114                  4523
# 2          France            4753             69                  4522
# 3         Germany            4838            106                  4384
# 4  United Kingdom            6608             99                  4681
# 5   United States           21768            273                 11158
#
#    Youth (<25)
# 0         4345
# 1         2301
# 2         1576
# 3         1699
# 4         2098
# 5         5641

# %%
df=df.set_index('Countries')
df
# Out:
#                 Adults (35-64)  Seniors (64+)  Young Adults (25-34)  \
# Countries
# Canada                    7089            114                  4523
# France                    4753             69                  4522
# Germany                   4838            106                  4384
# United Kingdom            6608             99                  4681
# United States            21768            273                 11158
#
#                 Youth (<25)
# Countries
# Canada                 2301
# France                 1576
# Germany                1699
# United Kingdom         2098
# United States          5641

# %%
df.plot()
# Out:
# <Axes: xlabel='Countries'>

# %%
df.plot(kind='line',title='Sales by Age Demographics', ylabel='Age Distributions',xlabel='Countries')
# Out:
# <Axes: title={'center': 'Sales by Age Demographics'}, xlabel='Countries', ylabel='Age Distributions'>

# %%
df.plot(kind='bar',title='Sales by Age Demographics', ylabel='Age Distributions',xlabel='Countries')
# Out:
# <Axes: title={'center': 'Sales by Age Demographics'}, xlabel='Countries', ylabel='Age Distributions'>

# %%
df.plot.barh(stacked=True)
# Out:
# <Axes: >

# %%
df.describe()
# Out:
#        Adults (35-64)  Seniors (64+)  Young Adults (25-34)  Youth (<25)
# count        6.000000       6.000000              6.000000     6.000000
# mean      9226.333333     119.833333           6383.166667  2943.333333
# std       6467.495734      78.136846           2953.921286  1660.555409
# min       4753.000000      58.000000           4384.000000  1576.000000
# 25%       5280.500000      76.500000           4522.250000  1798.750000
# 50%       6848.500000     102.500000           4602.000000  2199.500000
# 75%       9498.750000     112.000000           7943.500000  3834.000000
# max      21768.000000     273.000000          11158.000000  5641.000000
